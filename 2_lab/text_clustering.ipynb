# %%
import logging
import sys

import numpy as np

from time import time
from optparse import OptionParser
from sklearn.datasets import fetch_20newsgroups
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn import metrics

# %% [markdown]
# ### Выбираем категории новостей для последующей кластеризации

# %%
categories = [
    'alt.atheism',
    'talk.religion.misc',
    'comp.graphics',
    'sci.space',
]

# %% [markdown]
# ### Загружаем данные по выбранным категориям

# %%
dataset = fetch_20newsgroups(
    subset='all', 
    categories=categories,
    shuffle=True, 
    random_state=42
)

# %%
dataset.data[0] # type: ignore
# Out:
# 'From: healta@saturn.wwc.edu (Tammy R Healy)\nSubject: Re: who are we to judge, Bobby?\nLines: 38\nOrganization: Walla Walla College\nLines: 38\n\nIn article <1993Apr14.213356.22176@ultb.isc.rit.edu> snm6394@ultb.isc.rit.edu (S.N. Mozumder ) writes:\n>From: snm6394@ultb.isc.rit.edu (S.N. Mozumder )\n>Subject: Re: who are we to judge, Bobby?\n>Date: Wed, 14 Apr 1993 21:33:56 GMT\n>In article <healta.56.734556346@saturn.wwc.edu> healta@saturn.wwc.edu (TAMMY R HEALY) writes:\n>>Bobby,\n>>\n>>I would like to take the liberty to quote from a Christian writer named \n>>Ellen G. White.  I hope that what she said will help you to edit your \n>>remarks in this group in the future.\n>>\n>>"Do not set yourself as a standard.  Do not make your opinions, your views \n>>of duty, your interpretations of scripture, a criterion for others and in \n>>your heart condemn them if they do not come up to your ideal."\n>>                         Thoughts Fromthe Mount of Blessing p. 124\n>>\n>>I hope quoting this doesn\'t make the atheists gag, but I think Ellen White \n>>put it better than I could.\n>> \n>>Tammy\n>\n>Point?\n>\n>Peace,\n>\n>Bobby Mozumder\n>\nMy point is that you set up your views as the only way to believe.  Saying \nthat all eveil in this world is caused by atheism is ridiculous and \ncounterproductive to dialogue in this newsgroups.  I see in your posts a \nspirit of condemnation of the atheists in this newsgroup bacause they don\'\nt believe exactly as you do.  If you\'re here to try to convert the atheists \nhere, you\'re failing miserably.  Who wants to be in position of constantly \ndefending themselves agaist insulting attacks, like you seem to like to do?!\nI\'m sorry you\'re so blind that you didn\'t get the messgae in the quote, \neveryone else has seemed to.\n\nTammy\n'

# %%
labels = dataset.target # type: ignore
true_k = np.unique(labels).shape[0]

# %% [markdown]
# ### Создаём tf-idf векторизатор и преобразуем набор данных

# %%
vectorizer = TfidfVectorizer(
    max_df=0.5, 
    max_features=10000,
    min_df=2, 
    stop_words='english',
    use_idf=True
)

# %%
X = vectorizer.fit_transform(dataset.data) # type: ignore

# %% [markdown]
# ### Устанавливаем параметры для кластеризации и запускаем обучение модели

# %%
km = MiniBatchKMeans(
    n_clusters=true_k, 
    init='k-means++', 
    n_init=1,
    init_size=1000, 
    batch_size=1000, 
    verbose=True
)

# %%
km.fit(X)
# Out:
# Init 1/1 with method k-means++
# Inertia for init 1/1: 1910.1218960637032
# Minibatch step 1/338: mean batch inertia: 1.909955620307733
# Minibatch step 2/338: mean batch inertia: 0.9763105930806969, ewa inertia: 0.9763105930806969
# Minibatch step 3/338: mean batch inertia: 0.9734525323338511, ewa inertia: 0.974623426169926
# Minibatch step 4/338: mean batch inertia: 0.9714204095151264, ewa inertia: 0.9727326253111306
# Minibatch step 5/338: mean batch inertia: 0.9711383880543992, ewa inertia: 0.971791517131242
# Minibatch step 6/338: mean batch inertia: 0.9713605171966444, ewa inertia: 0.9715370897790592
# Minibatch step 7/338: mean batch inertia: 0.9697682023532994, ewa inertia: 0.9704928823258362
# Minibatch step 8/338: mean batch inertia: 0.9680811156273901, ewa inertia: 0.9690691711697287
# Minibatch step 9/338: mean batch inertia: 0.9690599025923492, ewa inertia: 0.9690636997545106
# Minibatch step 10/338: mean batch inertia: 0.9687430594012348, ewa inertia: 0.9688744197348672
# Minibatch step 11/338: mean batch inertia: 0.9693459865965209, ewa inertia: 0.9691527945056191
# Minibatch step 12/338: mean batch inertia: 0.9699049545242363, ewa inertia: 0.9695968086842597
# Minibatch step 13/338: mean batch inertia: 0.968500291428867, ewa inertia: 0.9689495139644293
# Minibatch step 14/338: mean batch inertia: 0.9698275493784205, ewa inertia: 0.9694678347519095
# Minibatch step 15/338: mean batch inertia: 0.9683480406092895, ewa inertia: 0.9688067992485918
# Minibatch step 16/338: mean batch inertia: 0.9678155472010118, ewa inertia: 0.9682216445569861
# Minibatch step 17/338: mean batch inertia: 0.9685085666921885, ewa inertia: 0.9683910200795378
# Minibatch step 18/338: mean batch inertia: 0.968687081181631, ewa inertia: 0.9685657905058029
# Minibatch step 19/338: mean batch inertia: 0.9687252585893812, ewa inertia: 0.9686599275090959
# Minibatch step 20/338: mean batch inertia: 0.9680196085482706, ewa inertia: 0.9682819352063655
# Minibatch step 21/338: mean batch inertia: 0.9693464386750617, ewa inertia: 0.9689103315869417
# Minibatch step 22/338: mean batch inertia: 0.9674717765252315, ewa inertia: 0.9680611255292615
# Minibatch step 23/338: mean batch inertia: 0.9682699625527381, ewa inertia: 0.968184405944537
# Minibatch step 24/338: mean batch inertia: 0.9689156935179437, ewa inertia: 0.9686160987269494
# Minibatch step 25/338: mean batch inertia: 0.9686178207626386, ewa inertia: 0.9686171152769429
# Minibatch step 26/338: mean batch inertia: 0.9690544424471208, ewa inertia: 0.9688752777150644
# Minibatch step 27/338: mean batch inertia: 0.9670392741153738, ewa inertia: 0.967791450324456
# Minibatch step 28/338: mean batch inertia: 0.9680094199471315, ewa inertia: 0.967920121884477
# Minibatch step 29/338: mean batch inertia: 0.9686809157609445, ewa inertia: 0.9683692327914826
# Minibatch step 30/338: mean batch inertia: 0.9689955187817018, ewa inertia: 0.9687389411682352
# Minibatch step 31/338: mean batch inertia: 0.9674812648616264, ewa inertia: 0.9679965112351722
# Minibatch step 32/338: mean batch inertia: 0.9674456009877599, ewa inertia: 0.9676712985743621
# Minibatch step 33/338: mean batch inertia: 0.9673046998564991, ewa inertia: 0.9674548884693663
# Minibatch step 34/338: mean batch inertia: 0.9677419535388785, ewa inertia: 0.9676243483687241
# Minibatch step 35/338: mean batch inertia: 0.9677132436116146, ewa inertia: 0.9676768248993559
# Minibatch step 36/338: mean batch inertia: 0.9674921577182243, ewa inertia: 0.9675678123957363
# Minibatch step 37/338: mean batch inertia: 0.9674178665237618, ewa inertia: 0.9674792965327053
# Minibatch step 38/338: mean batch inertia: 0.9677122513144525, ewa inertia: 0.9676168141134297
# Minibatch step 39/338: mean batch inertia: 0.9670842163463583, ewa inertia: 0.9673024116535293
# Minibatch step 40/338: mean batch inertia: 0.9679586702287027, ewa inertia: 0.96768981340983
# Minibatch step 41/338: mean batch inertia: 0.9672387736136362, ewa inertia: 0.9674235561511559
# Minibatch step 42/338: mean batch inertia: 0.9688655500740835, ewa inertia: 0.9682747922331675
# Minibatch step 43/338: mean batch inertia: 0.966343894218855, ewa inertia: 0.9671349468882369
# Minibatch step 44/338: mean batch inertia: 0.9677938238635293, ewa inertia: 0.9675238943352809
# Minibatch step 45/338: mean batch inertia: 0.9667808735576038, ewa inertia: 0.9670852752221303
# Minibatch step 46/338: mean batch inertia: 0.9670001696390081, ewa inertia: 0.9670350357987996
# Minibatch step 47/338: mean batch inertia: 0.967277326268745, ewa inertia: 0.9671780644115182
# Minibatch step 48/338: mean batch inertia: 0.9673826539333491, ewa inertia: 0.9672988374468374
# Minibatch step 49/338: mean batch inertia: 0.9680572219435919, ewa inertia: 0.9677465260517693
# Minibatch step 50/338: mean batch inertia: 0.9672000374174708, ewa inertia: 0.9674239235521834
# Minibatch step 51/338: mean batch inertia: 0.9678597887213102, ewa inertia: 0.9676812229436396
# Minibatch step 52/338: mean batch inertia: 0.9672962334762187, ewa inertia: 0.9674539564339459
# Minibatch step 53/338: mean batch inertia: 0.9668909508687814, ewa inertia: 0.9671216036800117
# Minibatch step 54/338: mean batch inertia: 0.9678265654934225, ewa inertia: 0.9675377558721078
# Minibatch step 55/338: mean batch inertia: 0.9670725260928519, ewa inertia: 0.9672631220000559
# Minibatch step 56/338: mean batch inertia: 0.9682125147518805, ewa inertia: 0.9678235663635887
# Converged (lack of improvement in inertia) at step 56/338
# MiniBatchKMeans(batch_size=1000, init_size=1000, n_clusters=4, n_init=1,
#                 verbose=True)

# %% [markdown]
# ### Получаем центры кластеров

# %%
order_centroids = km.cluster_centers_.argsort()[:, ::-1]

# %% [markdown]
# ### Выводим признаки, характеризующие центры кластеров

# %%
terms = vectorizer.get_feature_names_out()
for i in range(true_k):
    print("Cluster %d:" % i)
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind])
# Out:
# Cluster 0:
#  space
#  nasa
#  henry
#  toronto
#  gov
#  alaska
#  moon
#  shuttle
#  orbit
#  zoo
# Cluster 1:
#  god
#  com
#  people
#  sandvik
#  keith
#  jesus
#  don
#  article
#  say
#  think
# Cluster 2:
#  com
#  access
#  posting
#  nntp
#  host
#  university
#  digex
#  pat
#  article
#  know
# Cluster 3:
#  graphics
#  image
#  files
#  file
#  thanks
#  gif
#  images
#  university
#  com
#  ac
